# %% [markdown]
# # Exploring molecular energies using python
#
# # *In class activity 1*

# %% [markdown]
# **Exam question 1b from 2018 paper**

# %% [markdown]
# (b) 	Positronium is a hydrogen-like ‘atom’ containing one electron and one positron. The positron is a particle with the same mass as the electron, but the opposite charge. Observation of spectral signatures of positronium in space plays a significant role in astrophysics.
#
# The energy levels of the hydrogen atom (J Kg<sup>-1</sup>), as a function of the principal quantum number n, are given by:
#
# ![advanced%20hydrogen%20level.png](attachment:advanced%20hydrogen%20level.png)
#
#
# The analogous expression for positronium can be obtained by replacing the electron mass (*me*) with the reduced mass of the electron and positron.
#
# ***i)*** Compute the wavelength of the Lyman alpha (n=2→n=1) transition for positronium.
# (6 marks)
#
# *Addition: print your answer as an integer with units*
#
# ***ii)*** The ground state of positronium undergoes annihilation with a timescale of around 0.1 ns, in which all of the mass of the two particles is converted into two high-energy photons with the same wavelength. Calculate the wavelength of the emitted radiation. (Hint: E=mc**2)
# (6 marks)
#
# Scipy library: https://docs.scipy.org/doc/scipy/reference/constants.html

# %% [markdown]
# **Exam question 1b from 2019 paper**

# %% [markdown]
# (b) Polyynes are linear molecules with alternating single and triple chemical bonds. The smallest example, C<sub>4</sub>H<sub>2</sub>, is buta-1,3-diyne: H−C≡C−C≡C−H. The UV-vis absorption maximum for another polyyne, C<sub>8</sub>H<sub>2</sub>, is observed at 227 nm. The energy levels of a particle in a box of length L are given by
#
#
# ![Screen%20Shot%202019-03-30%20at%2009.56.04.png](attachment:Screen%20Shot%202019-03-30%20at%2009.56.04.png)
#
# (i) Polyyne molecules contain two degenerate π systems, πx and πy, which can be considered independently. How many πx electrons are there in C<sub>8</sub>H<sub>2</sub>?
# (1 mark) Use a simple calculation and in code comments to explain your answer.
#
# (ii) Using a particle-in-a-box model, calculate the length of the carbon chain in C<sub>8</sub>H<sub>2</sub>.
# (7 marks)
#
# (iii) Based on the same model, predict the wavelength of the absorption maximum for the C<sub>16</sub>H<sub>2</sub> system.(4 marks)
