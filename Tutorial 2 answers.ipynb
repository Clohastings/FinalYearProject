# %% [markdown]
# # Tutorial 2 answers

# %% [markdown]
# **Refresher Task:**

# %%
import scipy.constants as sc

# NOT PART OF THE TASK (working out delt_e)
w_nm_c4h2 = 218
w_m_c4h2 = w_nm_c4h2*1e-9
delt_e = (sc.h*sc.c)/w_m_c4h2
print(delt_e, "J")

#Now the task
na = 4
nb = 5
L_sq = (nb**2 - na**2)*(sc.h**2)/(8*sc.electron_mass*delt_e)

import math
L_m = math.sqrt(L_sq)
L_pm = L_m*1e12
print(L_pm,"pm")
# Out:
# 9.11213680812733e-19 J
# 771.3965163271837 pm

# %% [markdown]
# **Task 1**

# %%
def no_modes(n):
    return n+1

no_modes(3)
# Out:
# 4

# %% [markdown]
# **Task 2**

# %%
import scipy.constants
def en_photon(wave_nm):
    wave_m = wave_nm*1e-9
    en = sc.h*sc.c/wave_m
    return en
en_photon(225)
# Out:
# 8.828648107430037e-19

# %% [markdown]
# **Task 3**

# %%
import numpy as np
import matplotlib.pyplot as plt

#creating x coordinates
x_axis = np.linspace(-10,10)

#creating y coordinate
def line(m):
    y = m*x_axis
    return y
#plotting line
plt.plot(x_axis, line(3), color ='red')


plt.xlabel('X')
plt.ylabel('Y')
plt.title("Title", fontsize=16)
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# **Task 4**

# %%
import numpy as np
import matplotlib.pyplot as plt

#creating x coordinates
x = np.linspace(-4*np.pi,4*np.pi,50)
y = np.sin(x)

#plotting line
plt.plot(x, y)

# %% [markdown]
# **Assessment task: Incomplete graph**

# %%
#Part i)
def psi(n,L,x):
    return np.sqrt(2/L)*np.sin(n*np.pi*x/L)

x_list = np.linspace(0,1,100)
L = 1

#Part ii)
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,5)) 
plt.suptitle("Wave Functions", fontsize=18)

def psi(n,L,x):
    return np.sqrt(2/L)*np.sin(n*np.pi*x/L)

for n in [1]:
    psi_list = [] #Empty lists for energy and psi wave
    
    for x in x_list:
        psi_list.append(psi(n,L,x))
        
    plt.plot(x_list, psi_list)
    plt.xlabel("L", fontsize=13)
    plt.ylabel("Ψ", fontsize=13)
    plt.title("n="+str(n), fontsize=16)
    plt.grid()
